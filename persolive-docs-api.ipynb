# %% [markdown]
# # PersoLive API Commands Notebook
#
# This notebook contains all Python commands for each endpoint organized by module.
#
# Using terminal:
# - Set your API key as an environment variable: `export EST_LIVE_API_KEY="your-key"`
# - Use `--api-key` parameter in each command
#
# Using notebook:
# - Create a `.env` file in the project root with: `EST_LIVE_API_KEY=your-key`

# %% [markdown]
# ## Setting api_key and base_url

# %%
from dotenv import load_dotenv
import os
load_dotenv()

api_key = os.getenv('EST_LIVE_API_KEY')
base_url = "https://stage-platform.perso.ai" #stage

# %% [markdown]
# ## Test Connection

# %%
# Test API connection by checking available TTS types
# !cd ai-studio && EST_LIVE_API_KEY="{api_key}" python main.py \
--check-types tts_type \
--base-url {base_url}
# Out:
# 🤖 AI Studio API Client
# 🔗 Base URL: https://stage-platform.perso.ai
# ...
# 📡 Status Code: 200
# ✅ Available tts_type types (922 items):
#    1. nonexistant
#    2. dev
#    3. devin-onprem
#    4. yuri
#    5. openai-nova
#    6. hallym_m
#    7. k_idol_m_3_yoon_hajin
#    8. est_sports
#    9. openai-echo
#   10. dgbank
#   11. azure-openai-nova
#   12. hns_v2
#   13. chaehee
#   14. azuretts-en-US-AriaNeural-whispering
#   15. azuretts-en-AU-DuncanNeural-default
#   16. azuretts-ko-KR-YuJinNeural-default
#   17. azuretts-as-IN-YashicaNeural-default
#   18. azuretts-en-US-AvaNeural-angry
#   19. azuretts-ja-JP-DaichiNeural-default
#   20. azuretts-zh-CN-YunxiNeural-narration-relaxed
#   21. azuretts-en-US-JennyNeural-shouting
#   22. azuretts-zh-CN-XiaomengNeural-chat
#   23. azuretts-or-IN-SubhasiniNeural-default
#   24. azuretts-zh-CN-Yunyi:DragonHDFlashLatestNeural-captain
#   25. azuretts-es-MX-PelayoNeural-default
#   26. azuretts-en-US-NancyNeural-excited
# ...

# %% [markdown]
# ## 📹 Video Translation Module

# %% [markdown]
# ### ---- Main Translation Workflow

# %% [markdown]
# #### 1. Create Project & Export (Basic)

# %%
# !cd video-translation && EST_LIVE_API_KEY="{api_key}" python main.py \
  --input-file-url "https://samoonsikpoc.blob.core.windows.net/moonsikpoc/우영우_1_kor.mp4" \
  --source-language ko \
  --target-language en \
  --base-url {base_url}
# Out:
# 🎬 Starting video translation...
# 📁 Input file: 우영우_1_kor.mp4
# 🔗 Input URL: https://samoonsikpoc.blob.core.windows.net/moonsikpoc/우영우_1_kor.mp4
# 🌍 Source language: ko
# 🌍 Target language: en
# 💋 Lip-sync: Disabled
# 🏷️  Watermark: Enabled
# 🕒 Input file video duration: 0 seconds
# 👂 Input number of speakers: 1
# 🧪 Experiments: []
# 🔗 Input file source language subtitle URL: None
# ...
# ✅ Project pvtp-9c31300703b210b07e209953d5651e99 created successfully
#
# ...

# %% [markdown]
# #### 2. Create Project & Export (With Lip-sync, No Watermark)

# %%
# Create project with lip-sync enabled and watermark disabled
# !cd video-translation && EST_LIVE_API_KEY="{api_key}" python main.py \
  --input-file-url "https://samoonsikpoc.blob.core.windows.net/moonsikpoc/우영우_1_kor.mp4" \
  --source-language ko \
  --target-language en \
  --lipsync \
  --no-watermark \
  --base-url {base_url}
# Out:
# 🎬 Starting video translation...
# 📁 Input file: 우영우_1_kor.mp4
# 🔗 Input URL: https://samoonsikpoc.blob.core.windows.net/moonsikpoc/우영우_1_kor.mp4
# 🌍 Source language: ko
# 🌍 Target language: en
# 💋 Lip-sync: Enabled
# 🏷️  Watermark: Disabled
# 🕒 Input file video duration: 0 seconds
# 👂 Input number of speakers: 1
# 🧪 Experiments: []
# 🔗 Input file source language subtitle URL: None
# ...
# ✅ Project pvtp-1811dba82c504ea03bf9272ecb87b9c5 created successfully
#
# ...

# %% [markdown]
# #### 3. Create Project & Export (Full Options)

# %%
# Create project with all available options
# !cd video-translation && EST_LIVE_API_KEY="{api_key}" python main.py \
  --input-file-url "https://example.com/video.mp4" \
  --input-file-name "my-video.mp4" \
  --source-language ko \
  --target-language en \
  --input-dictionary-url "https://example.com/dict.json" \
  --base-url "https://live-api.perso.ai" \
  --lipsync \
  --no-watermark \
  --input-file-video-duration-sec 120 \
  --server-label "server1" \
  --perso-plan-name "plan1" \
  --input-number-of-speakers 2 \
  --input-file-source-language-subtitle-url "https://example.com/subtitle.srt" \
  --base-url {base_url}

# %% [markdown]
# ### ---- Modify Translation Workflow

# %%
# !cd video-translation && EST_LIVE_API_KEY="{api_key}" python main.py \
  --input-file-url "https://samoonsikpoc.blob.core.windows.net/moonsikpoc/우영우_1_kor.mp4" \
  --source-language ko \
  --target-language en \
  --base-url {base_url}

# %% [markdown]
# #### 4. Modify Translation (Using Script ID)

# %%
# Modify translation using script ID
# !cd video-translation && EST_LIVE_API_KEY="{api_key}" python modify_translation.py \
  --project-id "pvtp-uuid" \
  --script-id "pvts-uuid" \
  --text "New translation text" \
  --base-url {base_url}

# %% [markdown]
# #### 5. Modify Translation (Using Script Index)

# %%
# Modify translation using script index (0-based)
# !cd video-translation && EST_LIVE_API_KEY="{api_key}" python modify_translation.py \
  --project-id "pvtp-uuid" \
  --script-index 0 \
  --text "Modified translation" \
  --target-language en \
  --lipsync \
  --no-watermark \
  --base-url {base_url}

# %% [markdown]
# ## 💬 Live Chat Module

# %% [markdown]
# ### Settings & Configuration

# %% [markdown]
# #### 6. List Available LLM Types

# %%
# Get available LLM types
# !cd live-chat && EST_LIVE_API_KEY="{api_key}" python main.py \
--list-settings llm_type \
--api-server {base_url}
# Out:
# ⚠️  pyaudio is not installed, real-time audio features are limited.
#    Install: pip install pyaudio
# 🔍 Getting available llm_type...
# ✅ Retrieved 18 llm_type options
#
# 📋 Available llm_type:
#  1. gpt-4o
#  2. gpt-5-mini
#  3. claude-opus
#  4. gpt-41-nano
#  5. claude-sonnet
#  6. gpt-41
#  7. gpt-5-nano
#  8. azure-gpt-41
#  9. gpt-4o-mini
# 10. azure-gpt-4o
# 11. gpt-41-mini
# 12. gemini-25-flash
# 13. azure-gpt-41-mini
# 14. azure-gpt-41-nano
# 15. azure-gpt-5-mini-minimal
# 16. azure-gpt-5-low
# 17. azure-gpt-5-mini-low
# 18. azure-gpt-5-minimal

# %% [markdown]
# #### 7. List Available TTS Types

# %%
# Get available TTS types
# !cd live-chat && EST_LIVE_API_KEY="{api_key}" python main.py \
--list-settings tts_type \
--api-server {base_url}
# Out:
# ⚠️  pyaudio is not installed, real-time audio features are limited.
#    Install: pip install pyaudio
# 🔍 Getting available tts_type...
# ✅ Retrieved 922 tts_type options
#
# 📋 Available tts_type:
#  1. nonexistant - N/A
#  2. dev - N/A
#  3. devin-onprem - N/A
#  4. yuri - N/A
#  5. openai-nova - N/A
#  6. hallym_m - N/A
#  7. k_idol_m_3_yoon_hajin - N/A
#  8. est_sports - N/A
#  9. openai-echo - N/A
# 10. dgbank - N/A
# 11. azure-openai-nova - N/A
# 12. hns_v2 - N/A
# 13. chaehee - N/A
# 14. azuretts-en-US-AriaNeural-whispering - N/A
# 15. azuretts-en-AU-DuncanNeural-default - N/A
# 16. azuretts-ko-KR-YuJinNeural-default - N/A
# 17. azuretts-as-IN-YashicaNeural-default - N/A
# 18. azuretts-en-US-AvaNeural-angry - N/A
# 19. azuretts-ja-JP-DaichiNeural-default - N/A
# 20. azuretts-zh-CN-YunxiNeural-narration-relaxed - N/A
# 21. azuretts-en-US-JennyNeural-shouting - N/A
# 22. azuretts-zh-CN-XiaomengNeural-chat - N/A
# 23. azuretts-or-IN-SubhasiniNeural-default - N/A
# ...

# %% [markdown]
# #### 8. List Available Model Styles

# %%
# Get available model styles
# !cd live-chat && EST_LIVE_API_KEY="{api_key}" python main.py \
--list-settings modelstyle \
--api-server {base_url}
# Out:
# ⚠️  pyaudio is not installed, real-time audio features are limited.
#    Install: pip install pyaudio
# 🔍 Getting available modelstyle...
# ✅ Retrieved 81 modelstyle options
#
# 📋 Available modelstyle:
#  1. curi-front-navy_suit-fixed_short - N/A
#  2. hns-front-full_dress-nodded_loop - N/A
#  3. chaehee_livechat-front-white_blouse-greeting_loop - N/A
#  4. korean_f_2_hayoung-front-denim_overall_shorts-chair - N/A
#  5. korean_f_1_soohyun-front-mustang-chair - N/A
#  6. coreml-hayoung-front-bear_sweater-natural-224 - N/A
#  7. coreml-karin-front-pleated_blouse-natural-224 - N/A
#  8. coreml-julien-front-black_suit-natural-224 - N/A
#  9. coreml-ian-front-navy_shirt-natural-224 - N/A
# 10. coreml-curi-front-white_one_piece_dress-nod-224 - N/A
# 11. coreml-kimnayoon-front-beige_jacket-natural-224 - N/A
# 12. coreml-kimnayoon-front-pink_suspender-natural-224 - N/A
# 13. coreml-vikram-front-batik_shirt-natural-224 - N/A
# 14. coreml-yoonhajin-front-gray_coat-natural-224 - N/A
# ...

# %% [markdown]
# ### Chat Session Commands

# %% [markdown]
# #### 9. Start Chat Session (Basic)

# %%
# brew install portaudio
# pip install pyaudio

# %%
prod_api_key="plak-b0bfc5fce1302c42fc1ca59ca1fa1072"

# %%
import subprocess, os

message = "Hello there!"

cmd = [
    "python", "main.py",
    "--llm-type", "gpt-4o",
    "--capability", "LLM", "TTS"
]

# The simulated user input sequence:
input_sequence = f"1\n{message}\nn\n7\n"


subprocess.run(
    cmd,
    input=input_sequence,
    text=True,
    cwd="live-chat",
    env={**os.environ, "EST_LIVE_API_KEY": prod_api_key}
)

# %% [markdown]
# #### 10. Start Chat Session (Custom Configuration)

# %%
# Start chat session with custom LLM, TTS, and model style
# Note: This opens an interactive menu - use in terminal for full functionality
# !cd live-chat && EST_LIVE_API_KEY="{api_key}" python main.py \
  --llm-type "gpt-4" \
  --tts-type "azuretts-ko-KR-InJoonNeural-sad" \
  --model-style "indian_m_2_aaryan-side-white_jacket-natural" \
  --api-server {base_url}
# Out:
# ⚠️  pyaudio is not installed, real-time audio features are limited.
#    Install: pip install pyaudio
# 🚀 AI Avatar Chat System starting!
# 🔗 API Server: https://stage-platform.perso.ai
# ...
#
# ...
# 🤖 AI Avatar Chat Menu
# ...
# 1. Chat with text
# 2. Chat with voice (recording)
# 3. Chat with voice file
# 4. View chat history
# 5. Launch avatar visualization
# 6. Check available settings
# 7. Exit
# ...
# Choose option (1-7): ^C

# %% [markdown]
# #### 11. Start Chat Session (With Prompt and Document)

# %%
choice = 1
# !cd live-chat && echo {choice} | EST_LIVE_API_KEY="{api_key}" python main.py \
  --llm-type "gpt-4" \
  --tts-type "azuretts-ko-KR-InJoonNeural-sad" \
  --model-style "indian_m_2_aaryan-side-white_jacket-natural" \
  --prompt "plp-90ceb0870cd259abc6e2bfc5cd7415c2" \
  --document "pld-ad02c3f0cea3c47e8d3da623835ede5e" \
  --api-server {base_url}
# Out:
# ⚠️  pyaudio is not installed, real-time audio features are limited.
#    Install: pip install pyaudio
# 🚀 AI Avatar Chat System starting!
# 🔗 API Server: https://stage-platform.perso.ai
# ...
#
# ...
# 🤖 AI Avatar Chat Menu
# ...
# 1. Chat with text
# 2. Chat with voice (recording)
# 3. Chat with voice file
# 4. View chat history
# 5. Launch avatar visualization
# 6. Check available settings
# 7. Exit
# ...
# Choose option (1-7): 🤖 LLM Type: gpt-4
# 🔊 TTS Type: azuretts-ko-KR-InJoonNeural-sad
# 🎤 STT Type: default
# 👤 Model Style: indian_m_2_aaryan-side-white_jacket-natural
# 📝 Prompt ID: plp-90ceb0870cd259abc6e2bfc5cd7415c2
# 📄 Document ID: pld-ad02c3f0cea3c47e8d3da623835ede5e
# ⚡ Capabilities: LLM, TTS, STT
# ...
# 📝 Creating session...
#
# ...

# %% [markdown]
# #### 12. Start Chat Session (With MCP Servers and Tools)

# %%
# Start chat session with MCP servers and tools
# Note: This opens an interactive menu - use in terminal for full functionality
# !cd live-chat && EST_LIVE_API_KEY="{api_key}" python main.py \
  --mcp-servers "server1,server2" \
  --tools "tool1,tool2" \
  --capability LLM TTS STT \
  --api-server {base_url}
# Out:
# ⚠️  pyaudio is not installed, real-time audio features are limited.
#    Install: pip install pyaudio
# 🚀 AI Avatar Chat System starting!
# 🔗 API Server: https://stage-platform.perso.ai
# ...
#
# ...
# 🤖 AI Avatar Chat Menu
# ...
# 1. Chat with text
# 2. Chat with voice (recording)
# 3. Chat with voice file
# 4. View chat history
# 5. Launch avatar visualization
# 6. Check available settings
# 7. Exit
# ...
# Choose option (1-7): ^C

# %% [markdown]
# ## 🎨 AI Studio Module

# %% [markdown]
# ### ---- Check Available Types

# %% [markdown]
# #### 13. Check Available TTS Types

# %%
# List all available TTS types
# !cd ai-studio && EST_LIVE_API_KEY="{api_key}" python main.py --check-types tts_type --base-url {base_url}
# Out:
# 🤖 AI Studio API Client
# 🔗 Base URL: https://stage-platform.perso.ai
# ...
# 📡 Status Code: 200
# ✅ Available tts_type types (922 items):
#    1. nonexistant
#    2. dev
#    3. devin-onprem
#    4. yuri
#    5. openai-nova
#    6. hallym_m
#    7. k_idol_m_3_yoon_hajin
#    8. est_sports
#    9. openai-echo
#   10. dgbank
#   11. azure-openai-nova
#   12. hns_v2
#   13. chaehee
#   14. azuretts-en-US-AriaNeural-whispering
#   15. azuretts-en-AU-DuncanNeural-default
#   16. azuretts-ko-KR-YuJinNeural-default
#   17. azuretts-as-IN-YashicaNeural-default
#   18. azuretts-en-US-AvaNeural-angry
#   19. azuretts-ja-JP-DaichiNeural-default
#   20. azuretts-zh-CN-YunxiNeural-narration-relaxed
#   21. azuretts-en-US-JennyNeural-shouting
#   22. azuretts-zh-CN-XiaomengNeural-chat
#   23. azuretts-or-IN-SubhasiniNeural-default
#   24. azuretts-zh-CN-Yunyi:DragonHDFlashLatestNeural-captain
#   25. azuretts-es-MX-PelayoNeural-default
#   26. azuretts-en-US-NancyNeural-excited
# ...

# %% [markdown]
# #### 14. Check Available Model Styles

# %%
# List all available model styles
# !cd ai-studio && EST_LIVE_API_KEY="{api_key}" python main.py --check-types modelstyle --base-url {base_url}
# Out:
# 🤖 AI Studio API Client
# 🔗 Base URL: https://stage-platform.perso.ai
# ...
# 📡 Status Code: 200
# ✅ Available modelstyle types (81 items):
#    1. curi-front-navy_suit-fixed_short
#    2. hns-front-full_dress-nodded_loop
#    3. chaehee_livechat-front-white_blouse-greeting_loop
#    4. korean_f_2_hayoung-front-denim_overall_shorts-chair
#    5. korean_f_1_soohyun-front-mustang-chair
#    6. coreml-hayoung-front-bear_sweater-natural-224
#    7. coreml-karin-front-pleated_blouse-natural-224
#    8. coreml-julien-front-black_suit-natural-224
#    9. coreml-ian-front-navy_shirt-natural-224
#   10. coreml-curi-front-white_one_piece_dress-nod-224
#   11. coreml-kimnayoon-front-beige_jacket-natural-224
#   12. coreml-kimnayoon-front-pink_suspender-natural-224
#   13. coreml-vikram-front-batik_shirt-natural-224
#   14. coreml-yoonhajin-front-gray_coat-natural-224
#   15. coreml-rima-front-gray_suit-natural-224
#   16. coreml-seoyeonhee-front-white_shirt-natural-224
# ...

# %% [markdown]
# #### 15. Check Available STT Types

# %%
# List all available STT types
# !cd ai-studio && EST_LIVE_API_KEY="{api_key}" python main.py --check-types stt_type --base-url {base_url}
# Out:
# 🤖 AI Studio API Client
# 🔗 Base URL: https://stage-platform.perso.ai
# ...
# 📡 Status Code: 200
# ✅ Available stt_type types (3 items):
#    1. default
#    2. gpt-4o-mini-transcribe
#    3. gpt-4o-transcribe

# %% [markdown]
# #### 16. Check Available MCP Types

# %%
# List all available MCP types
# !cd ai-studio && EST_LIVE_API_KEY="{api_key}" python main.py --check-types mcp_type --base-url {base_url}
# Out:
# 🤖 AI Studio API Client
# 🔗 Base URL: https://stage-platform.perso.ai
# ...
# 📡 Status Code: 200
# ✅ Available mcp_type types (2 items):
#    1. time-mcp
#    2. Coin MCP

# %% [markdown]
# ### ----- TTS + STF Workflow

# %% [markdown]
# #### 17. TTS + STF (Basic)

# %%
# Basic TTS + STF workflow
# !cd ai-studio && EST_LIVE_API_KEY="{api_key}" python main.py \
  --tts-text "Hello world" \
  --tts-type "yuri" \
  --stf-model-style "yoori-front-khaki_overalls-nodded_loop" \
  --base-url {base_url}

# %% [markdown]
# #### 18. TTS + STF (Multiple Texts)

# %%
# TTS with multiple texts
# !cd ai-studio && EST_LIVE_API_KEY="{api_key}" python main.py \
  --tts-text "Hello" "I am AI" "How are you?" \
  --tts-type "azuretts-ko-KR-InJoonNeural-sad" \
  --stf-model-style "yoori-front-khaki_overalls-nodded_loop" \
  --base-url {base_url}

# %% [markdown]
# #### 19. TTS Only (Skip STF)

# %%
# TTS only, skip STF generation
# !cd ai-studio && EST_LIVE_API_KEY="{api_key}" python main.py \
  --tts-text "Hello world" \
  --tts-type "yuri" \
  --skip-stf \
  --base-url {base_url}

# %% [markdown]
# #### 20. TTS + STF (Full Options)

# %%
# TTS + STF with all available options
# !cd ai-studio && EST_LIVE_API_KEY="{api_key}" python main.py \
  --tts-text "Hello world" \
  --tts-type "yuri" \
  --tts-audio-format "wav_16bit_32000hz_mono" \
  --stf-model-style "yoori-front-khaki_overalls-nodded_loop" \
  --base-url base_url \
  --agent "1" \
  --save-dir "./my-outputs" \
  --webhook_url "https://example.com/webhook"

# %% [markdown]
# ### ---- Photo Avatar Workflow

# %% [markdown]
# #### 21. TTS + Photo Avatar (Basic)

# %%
# TTS + Photo Avatar workflow
# !cd ai-studio &&  EST_LIVE_API_KEY="{api_key}" python main.py \
  --tts-text "Hello world" \
  --tts-type "openai-nova" \
  --skip-stf \
  --photo-avatar-input-image "https://framerusercontent.com/images/mlBqjSd2ybBAQeYc9S9yG1SFJ8.png" \
  --base-url {base_url}
# Out:
# 🤖 AI Studio API Client
# 🔗 Base URL: https://stage-platform.perso.ai
# ...
# 🎵 Starting TTS task...
# 📝 Texts: ['Hello world']
# 🔊 TTS Type: openai-nova
# 🎛️  Audio Format: wav_16bit_32000hz_mono
# ⏳ TTS task started (Task ID: pst-33b89491954307c561da541456e4f323)
# ⏳ TTS task status: COMPLETED
# ✅ Audio file downloaded: user-uploads/74b5b0a7-53c5-4b14-8b65-b29d5efe58a3.wav
#
# 🎉 TTS task completed successfully!
# 🎵 Audio URL: https://stgpersolive.blob.core.windows.net/user-uploads/perso-studio-task/audio/74b5b0a7-53c5-4b14-8b65-b29d5efe58a3.wav?se=2025-11-11T06%3A16%3A55Z&sp=r&sv=2024-11-04&sr=b&sig=GzPx15LFzTBajRJDXtUkLCo%2BasN7ZpbaZhJKb84tlhc%3D
# 🎵 Audio file: user-uploads/74b5b0a7-53c5-4b14-8b65-b29d5efe58a3.wav
# 🎭 Starting Photo Avatar task...
# 🖼️ Input image: https://framerusercontent.com/images/mlBqjSd2ybBAQeYc9S9yG1SFJ8.png
# ...

# %% [markdown]
# #### 22. TTS + STF + Photo Avatar (Complete)

# %%
# Complete workflow: TTS + STF + Photo Avatar
# !cd ai-studio && EST_LIVE_API_KEY="{api_key}" python main.py \
  --tts-text "Welcome to PERSO Platform." \
  --tts-type "openai-nova" \
  --stf-model-style "yoori-front-khaki_overalls-nodded_loop" \
  --photo-avatar-input-image "https://framerusercontent.com/images/mlBqjSd2ybBAQeYc9S9yG1SFJ8.png" \
  --base-url {base_url}
# Out:
# 🤖 AI Studio API Client
# 🔗 Base URL: https://stage-platform.perso.ai
# ...
# 🎵 Starting TTS task...
# 📝 Texts: ['Welcome to PERSO Platform.']
# 🔊 TTS Type: openai-nova
# 🎛️  Audio Format: wav_16bit_32000hz_mono
# ⏳ TTS task started (Task ID: pst-1025def5e670e702f5e6aa1169708591)
# ⏳ TTS task status: COMPLETED
# ✅ Audio file downloaded: user-uploads/55309eaa-86e3-4767-a029-ce9ee80c7b3d.wav
#
# 🎉 TTS task completed successfully!
# 🎵 Audio URL: https://stgpersolive.blob.core.windows.net/user-uploads/perso-studio-task/audio/55309eaa-86e3-4767-a029-ce9ee80c7b3d.wav?se=2025-11-11T02%3A21%3A29Z&sp=r&sv=2024-11-04&sr=b&sig=P3Ouc4owh%2BNMd7xmIOIyN4gEkkvk1EJagBWeP3455bA%3D
# 🎵 Audio file: user-uploads/55309eaa-86e3-4767-a029-ce9ee80c7b3d.wav
# 🎭 Starting STF task...
# 🎵 Input audio: user-uploads/55309eaa-86e3-4767-a029-ce9ee80c7b3d.wav
# 👤 Model style: yoori-front-khaki_overalls-nodded_loop
# ⏳ STF task started (Task ID: pst-bafbfd83bf41ad63958c1a00a3e06e09)
# ⏳ STF task status: PROCESSING
# ...

# %% [markdown]
# #### 23. Photo Avatar Only (Skip STF)

# %%
# Photo Avatar only, skip STF
# !cd ai-studio &&  EST_LIVE_API_KEY="{api_key}" python main.py \
  --tts-text "Welcome to PERSO Platform." \
  --tts-type "azuretts-ko-KR-YuJinNeural-default" \
  --skip-stf \
  --photo-avatar-input-image "https://i.postimg.cc/C5xn15nV/jiwoo.png" \
  --base-url {base_url} \
  --set-timeout 60
# Out:
# 🤖 AI Studio API Client
# 🔗 Base URL: https://stage-platform.perso.ai
# ...
# 🎵 Starting TTS task...
# 📝 Texts: ['Welcome to PERSO Platform.']
# 🔊 TTS Type: azuretts-ko-KR-YuJinNeural-default
# 🎛️  Audio Format: wav_16bit_32000hz_mono
# ⏳ TTS task started (Task ID: pst-4110debb82ea55d331d35b381b97ba01)
# ⏳ TTS task status: COMPLETED
# ✅ Audio file downloaded: user-uploads/13253be1-3ee8-409f-be34-16f9100b1a1d.wav
#
# 🎉 TTS task completed successfully!
# 🎵 Audio URL: https://stgpersolive.blob.core.windows.net/user-uploads/perso-studio-task/audio/13253be1-3ee8-409f-be34-16f9100b1a1d.wav?se=2025-11-11T02%3A57%3A20Z&sp=r&sv=2024-11-04&sr=b&sig=pm08aUsKBsoTQ3h9g/z3VOey5x4wjix5PeUTHjpGLFE%3D
# 🎵 Audio file: user-uploads/13253be1-3ee8-409f-be34-16f9100b1a1d.wav
# 🎭 Starting Photo Avatar task...
# 🖼️ Input image: https://i.postimg.cc/C5xn15nV/jiwoo.png
# ...

# %%
# Photo Avatar only, skip STF
# !cd ai-studio &&  EST_LIVE_API_KEY="{api_key}" python main.py \
  --tts-text "Hello world" \
  --tts-type "openai-nova" \
  --skip-stf \
  --photo-avatar-input-image "https://framerusercontent.com/images/mlBqjSd2ybBAQeYc9S9yG1SFJ8.png" \
  --base-url {base_url} \
  --set-timeout 60
# Out:
# 🤖 AI Studio API Client
# 🔗 Base URL: https://stage-platform.perso.ai
# ...
# 🎵 Starting TTS task...
# 📝 Texts: ['Hello world']
# 🔊 TTS Type: openai-nova
# 🎛️  Audio Format: wav_16bit_32000hz_mono
# ⏳ TTS task started (Task ID: pst-b15ac172f1de68e1bd7412242a2cd9d4)
# ⏳ TTS task status: COMPLETED
# ✅ Audio file downloaded: user-uploads/4dccc04f-8ce1-4cf7-89b2-f1e7e692d8d8.wav
#
# 🎉 TTS task completed successfully!
# 🎵 Audio URL: https://stgpersolive.blob.core.windows.net/user-uploads/perso-studio-task/audio/4dccc04f-8ce1-4cf7-89b2-f1e7e692d8d8.wav?se=2025-11-11T02%3A09%3A54Z&sp=r&sv=2024-11-04&sr=b&sig=RnRTaNqzPYDhGukf3DTVCjHvOjTfK7mGFXQnH9LVTek%3D
# 🎵 Audio file: user-uploads/4dccc04f-8ce1-4cf7-89b2-f1e7e692d8d8.wav
# 🎭 Starting Photo Avatar task...
# 🖼️ Input image: https://framerusercontent.com/images/mlBqjSd2ybBAQeYc9S9yG1SFJ8.png
# ...
